# %%
from euclidianNetwork import EuclidianNetwork
from isingNetwork import IsingModel
import numpy as np

# %%
g = EuclidianNetwork(100,1.4)
g.show()
g.show_adjacency_matrix()
# Out:
# <100x100 sparse array of type '<class 'numpy.intc'>'
# 	with 330 stored elements in Compressed Sparse Row format>

# %%
model = IsingModel(g.get_graph())

temp_range = np.arange(0,13,0.1)

model.iterate(temp_range, 10000)
# Out:
# [{'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33333333333333337,
#   'susceptibility_per_spin': inf,
#   'specific_heat_per_spin': inf},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33333333333333337,
#   'susceptibility_per_spin': 2500000.0,
#   'specific_heat_per_spin': 68062499.99999999},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33333333333333337,
#   'susceptibility_per_spin': 1250000.0,
#   'specific_heat_per_spin': 17015624.999999996},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33333333333333337,
#   'susceptibility_per_spin': 833333.3333333331,
#   'specific_heat_per_spin': 7562499.999999998},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33333333333333337,
#   'susceptibility_per_spin': 625000.0,
#   'specific_heat_per_spin': 4253906.249999999},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33333333333333337,
#   'susceptibility_per_spin': 500000.0,
#   'specific_heat_per_spin': 2722500.0},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33328805337111955,
#   'susceptibility_per_spin': 415928.0594933333,
#   'specific_heat_per_spin': 1886579.8410666662},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33329286738363073,
#   'susceptibility_per_spin': 356579.8262799999,
#   'specific_heat_per_spin': 1386387.5787428566},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.333116292551467,
#   'susceptibility_per_spin': 310031.59949999995,
#   'specific_heat_per_spin': 1052563.7349999999},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33263570374877616,
#   'susceptibility_per_spin': 272292.8124044445,
#   'specific_heat_per_spin': 821949.7372790123},
#  {'magnetization_per_spin': 1.0,
#   'energy': -165.0,
#   'binder_cumulant': 0.33183956991233166,
#   'susceptibility_per_spin': 242850.41990000004,
#   'specific_heat_per_spin': 657884.146556},
#  {'magnetization_per_spin': 0.98,
#   'energy': -161.0,
#   'binder_cumulant': 0.32755687654637533,
#   'susceptibility_per_spin': 212787.89933090907,
#   'specific_heat_per_spin': 533191.4352363634},
#  {'magnetization_per_spin': 0.94,
#   'energy': -153.0,
#   'binder_cumulant': 0.329942518598603,
#   'susceptibility_per_spin': 189920.09410333328,
#   'specific_heat_per_spin': 427956.809086111},
#  {'magnetization_per_spin': 0.98,
#   'energy': -159.0,
#   'binder_cumulant': 0.32265662367374115,
#   'susceptibility_per_spin': 163041.78473538457,
#   'specific_heat_per_spin': 346422.6487668639},
#  {'magnetization_per_spin': 0.84,
#   'energy': -143.0,
#   'binder_cumulant': 0.3239204072818911,
#   'susceptibility_per_spin': 148642.49992857143,
#   'specific_heat_per_spin': 289098.4528142856},
#  {'magnetization_per_spin': 0.96,
#   'energy': -155.0,
#   'binder_cumulant': 0.3124487627585749,
#   'susceptibility_per_spin': 130549.48447733335,
#   'specific_heat_per_spin': 233289.16906488888},
#  {'magnetization_per_spin': 0.52,
#   'energy': -105.0,
#   'binder_cumulant': 0.11108625221257362,
#   'susceptibility_per_spin': 31545.737297500003,
#   'specific_heat_per_spin': 145489.50559999997},
#  {'magnetization_per_spin': 0.9,
#   'energy': -147.0,
#   'binder_cumulant': 0.2800060002897845,
#   'susceptibility_per_spin': 91156.95453882353,
#   'specific_heat_per_spin': 154165.82995709343},
#  {'magnetization_per_spin': 0.82,
#   'energy': -143.0,
#   'binder_cumulant': 0.2866585462593798,
#   'susceptibility_per_spin': 84731.6372422222,
#   'specific_heat_per_spin': 129146.74181604935},
#  {'magnetization_per_spin': 0.44,
#   'energy': -71.0,
#   'binder_cumulant': 0.28378505024297374,
#   'susceptibility_per_spin': 69988.54312421053,
#   'specific_heat_per_spin': 105090.96038116343},
#  {'magnetization_per_spin': -0.18,
#   'energy': -99.0,
#   'binder_cumulant': -0.15762586040010418,
#   'susceptibility_per_spin': 49508.24286199999,
#   'specific_heat_per_spin': 79152.384639},
#  {'magnetization_per_spin': 0.4,
#   'energy': -77.0,
#   'binder_cumulant': 0.24038811964858298,
#   'susceptibility_per_spin': 44816.122788571425,
#   'specific_heat_per_spin': 65731.75751111111},
#  {'magnetization_per_spin': -0.26,
#   'energy': -111.0,
#   'binder_cumulant': -0.610699785615022,
#   'susceptibility_per_spin': 11034.507454545454,
#   'specific_heat_per_spin': 37326.80080578511},
#  {'magnetization_per_spin': -0.32,
#   'energy': -93.0,
#   'binder_cumulant': -0.6998868794149717,
#   'susceptibility_per_spin': 23897.44197565217,
#   'specific_heat_per_spin': 35937.220015879015},
#  {'magnetization_per_spin': 0.42,
#   'energy': -101.0,
#   'binder_cumulant': -0.15598239071851672,
#   'susceptibility_per_spin': 25743.72233999999,
#   'specific_heat_per_spin': 42035.431971527774},
#  {'magnetization_per_spin': 0.04,
#   'energy': -61.0,
#   'binder_cumulant': -0.44831762416111,
#   'susceptibility_per_spin': 17858.610839999998,
#   'specific_heat_per_spin': 27343.484866560004},
#  {'magnetization_per_spin': 0.18,
#   'energy': -47.0,
#   'binder_cumulant': -0.0651293693910946,
#   'susceptibility_per_spin': 20932.177290769232,
#   'specific_heat_per_spin': 26328.95312130177},
#  {'magnetization_per_spin': -0.28,
#   'energy': -81.0,
#   'binder_cumulant': -1.4393531272513922,
#   'susceptibility_per_spin': 8732.906653333333,
#   'specific_heat_per_spin': 16419.260948696847},
#  {'magnetization_per_spin': -0.3,
#   'energy': -85.0,
#   'binder_cumulant': -0.3913455535685013,
#   'susceptibility_per_spin': 14882.846165714282,
#   'specific_heat_per_spin': 17104.889734183667},
#  {'magnetization_per_spin': -0.22,
#   'energy': -77.0,
#   'binder_cumulant': -0.24753903148945544,
#   'susceptibility_per_spin': 15010.336877241376,
#   'specific_heat_per_spin': 17907.560142211652},
#  {'magnetization_per_spin': -0.3,
#   'energy': -65.0,
#   'binder_cumulant': -0.9650815651218656,
#   'susceptibility_per_spin': 4211.810133333333,
#   'specific_heat_per_spin': 13793.624033777778},
#  {'magnetization_per_spin': -0.16,
#   'energy': -61.0,
#   'binder_cumulant': -0.8353650042289265,
#   'susceptibility_per_spin': 4865.353340645162,
#   'specific_heat_per_spin': 10429.014416649321},
#  {'magnetization_per_spin': -0.02,
#   'energy': -33.0,
#   'binder_cumulant': -0.48124128077209005,
#   'susceptibility_per_spin': 1939.4078799999997,
#   'specific_heat_per_spin': 8918.254056249998},
#  {'magnetization_per_spin': -0.1,
#   'energy': -57.0,
#   'binder_cumulant': -0.8888431792008606,
#   'susceptibility_per_spin': 4975.185938181818,
#   'specific_heat_per_spin': 8478.966242791548},
#  {'magnetization_per_spin': -0.28,
#   'energy': -51.0,
#   'binder_cumulant': -1.3035602000044224,
#   'susceptibility_per_spin': 4362.325542352942,
#   'specific_heat_per_spin': 7592.364924221453},
#  {'magnetization_per_spin': -0.12,
#   'energy': -71.0,
#   'binder_cumulant': -0.6817574319262507,
#   'susceptibility_per_spin': 7554.633050285715,
#   'specific_heat_per_spin': 7721.077518367348},
#  {'magnetization_per_spin': 0.18,
#   'energy': -47.0,
#   'binder_cumulant': -0.8721781665447284,
#   'susceptibility_per_spin': 4755.400000000001,
#   'specific_heat_per_spin': 6225.198021913579},
#  {'magnetization_per_spin': -0.02,
#   'energy': -53.0,
#   'binder_cumulant': -0.7183764278122748,
#   'susceptibility_per_spin': 3156.0121254054047,
#   'specific_heat_per_spin': 5917.983366252738},
#  {'magnetization_per_spin': 0.22,
#   'energy': -37.0,
#   'binder_cumulant': -1.4093004775652074,
#   'susceptibility_per_spin': 2818.1567957894736,
#   'specific_heat_per_spin': 4458.526891689749},
#  {'magnetization_per_spin': -0.24,
#   'energy': -43.0,
#   'binder_cumulant': -0.9235899420542062,
#   'susceptibility_per_spin': 3463.059806153846,
#   'specific_heat_per_spin': 4818.534140959893},
#  {'magnetization_per_spin': -0.34,
#   'energy': -57.0,
#   'binder_cumulant': -0.3774404320798299,
#   'susceptibility_per_spin': 3930.955599,
#   'specific_heat_per_spin': 4249.940919750001},
#  {'magnetization_per_spin': -0.02,
#   'energy': -61.0,
#   'binder_cumulant': -1.0031066772816573,
#   'susceptibility_per_spin': 3469.598820487805,
#   'specific_heat_per_spin': 4250.3456035693025},
#  {'magnetization_per_spin': -0.3,
#   'energy': -45.0,
#   'binder_cumulant': -0.8738025274136063,
#   'susceptibility_per_spin': 2186.1348561904765,
#   'specific_heat_per_spin': 2934.0056517006797},
#  {'magnetization_per_spin': -0.28,
#   'energy': -61.0,
#   'binder_cumulant': -0.7335575072754719,
#   'susceptibility_per_spin': 2991.402980465117,
#   'specific_heat_per_spin': 2969.382723418064},
#  {'magnetization_per_spin': -0.04,
#   'energy': -45.0,
#   'binder_cumulant': -0.9541347987473903,
#   'susceptibility_per_spin': 2920.4669090909088,
#   'specific_heat_per_spin': 2563.947566942148},
#  {'magnetization_per_spin': 0.04,
#   'energy': -41.0,
#   'binder_cumulant': -0.9963405024471359,
#   'susceptibility_per_spin': 3819.7331057777774,
#   'specific_heat_per_spin': 2911.354291358025},
#  {'magnetization_per_spin': -0.34,
#   'energy': -43.0,
#   'binder_cumulant': -0.7251133118026967,
#   'susceptibility_per_spin': 2027.0647921739128,
#   'specific_heat_per_spin': 1954.697359357277},
#  {'magnetization_per_spin': 0.32,
#   'energy': -39.0,
#   'binder_cumulant': -0.5001586695480851,
#   'susceptibility_per_spin': 2483.1974119148936,
#   'specific_heat_per_spin': 1798.7772023540062},
#  {'magnetization_per_spin': 0.14,
#   'energy': -37.0,
#   'binder_cumulant': -0.7244328996407146,
#   'susceptibility_per_spin': 1775.4646633333332,
#   'specific_heat_per_spin': 1922.9182715277775},
#  {'magnetization_per_spin': 0.08,
#   'energy': -47.0,
#   'binder_cumulant': -1.0042361888148887,
#   'susceptibility_per_spin': 1704.7296644897958,
#   'specific_heat_per_spin': 1928.8512213244478},
#  {'magnetization_per_spin': -0.02,
#   'energy': -41.0,
#   'binder_cumulant': -0.8059545932728698,
#   'susceptibility_per_spin': 2056.5170552,
#   'specific_heat_per_spin': 1916.6766040000002},
#  {'magnetization_per_spin': -0.08,
#   'energy': -27.0,
#   'binder_cumulant': -0.9317741258507475,
#   'susceptibility_per_spin': 1857.0305686274507,
#   'specific_heat_per_spin': 1553.4761213379466},
#  {'magnetization_per_spin': 0.14,
#   'energy': -41.0,
#   'binder_cumulant': -0.8323947442210224,
#   'susceptibility_per_spin': 2013.4723684615385,
#   'specific_heat_per_spin': 1390.8564964497039},
#  {'magnetization_per_spin': 0.12,
#   'energy': -55.0,
#   'binder_cumulant': -1.2351908345976983,
#   'susceptibility_per_spin': 1663.4977199999996,
#   'specific_heat_per_spin': 1602.5038705589175},
#  {'magnetization_per_spin': -0.06,
#   'energy': -25.0,
#   'binder_cumulant': -1.1600151408470865,
#   'susceptibility_per_spin': 1403.1596970370372,
#   'specific_heat_per_spin': 1413.7643400548698},
#  {'magnetization_per_spin': -0.14,
#   'energy': -21.0,
#   'binder_cumulant': -0.48790977871698993,
#   'susceptibility_per_spin': 1613.4705272727276,
#   'specific_heat_per_spin': 972.7734901157024},
#  {'magnetization_per_spin': 0.02,
#   'energy': -25.0,
#   'binder_cumulant': -0.6593864299824137,
#   'susceptibility_per_spin': 2031.0190599999996,
#   'specific_heat_per_spin': 1046.739545790816},
#  {'magnetization_per_spin': -0.06,
#   'energy': -1.0,
#   'binder_cumulant': -0.9878760651340841,
#   'susceptibility_per_spin': 1744.2299621052628,
#   'specific_heat_per_spin': 937.445178701139},
#  {'magnetization_per_spin': 0.1,
#   'energy': -19.0,
#   'binder_cumulant': -0.7434822770978928,
#   'susceptibility_per_spin': 1490.1271551724137,
#   'specific_heat_per_spin': 945.219072413793},
#  {'magnetization_per_spin': -0.1,
#   'energy': -33.0,
#   'binder_cumulant': -1.0103969657532166,
#   'susceptibility_per_spin': 1428.004813559322,
#   'specific_heat_per_spin': 849.6598438379775},
#  {'magnetization_per_spin': -0.22,
#   'energy': -27.0,
#   'binder_cumulant': -0.8150256143413863,
#   'susceptibility_per_spin': 1416.4909326666668,
#   'specific_heat_per_spin': 961.7346128888889},
#  {'magnetization_per_spin': -0.24,
#   'energy': -21.0,
#   'binder_cumulant': -0.9467858343586191,
#   'susceptibility_per_spin': 1909.3735547540982,
#   'specific_heat_per_spin': 1019.6647245364146},
#  {'magnetization_per_spin': 0.2,
#   'energy': -7.0,
#   'binder_cumulant': -1.090039820048737,
#   'susceptibility_per_spin': 1657.8912412903223,
#   'specific_heat_per_spin': 742.9537971904266},
#  {'magnetization_per_spin': -0.34,
#   'energy': -49.0,
#   'binder_cumulant': -0.57059017127492,
#   'susceptibility_per_spin': 1603.4051295238096,
#   'specific_heat_per_spin': 787.9562303854872},
#  {'magnetization_per_spin': -0.1,
#   'energy': -23.0,
#   'binder_cumulant': -0.8987416209284209,
#   'susceptibility_per_spin': 1396.2052975,
#   'specific_heat_per_spin': 638.3397647460937},
#  {'magnetization_per_spin': -0.16,
#   'energy': -35.0,
#   'binder_cumulant': -1.0501904299145823,
#   'susceptibility_per_spin': 1426.1441175384614,
#   'specific_heat_per_spin': 591.5286872426036},
#  {'magnetization_per_spin': -0.14,
#   'energy': -29.0,
#   'binder_cumulant': -0.6617218418921229,
#   'susceptibility_per_spin': 1140.3339387878789,
#   'specific_heat_per_spin': 672.3999888888886},
#  {'magnetization_per_spin': 0.08,
#   'energy': -31.0,
#   'binder_cumulant': -1.6392812715296414,
#   'susceptibility_per_spin': 1089.4628083582088,
#   'specific_heat_per_spin': 539.1236234350635},
#  {'magnetization_per_spin': -0.02,
#   'energy': -29.0,
#   'binder_cumulant': -1.1142552019712109,
#   'susceptibility_per_spin': 1310.0232941176469,
#   'specific_heat_per_spin': 493.9412137543252},
#  {'magnetization_per_spin': -0.16,
#   'energy': -29.0,
#   'binder_cumulant': -0.644641588164822,
#   'susceptibility_per_spin': 1709.761797101449,
#   'specific_heat_per_spin': 559.1763340474689},
#  {'magnetization_per_spin': 0.16,
#   'energy': -37.0,
#   'binder_cumulant': -0.8996592841356033,
#   'susceptibility_per_spin': 1355.148845142857,
#   'specific_heat_per_spin': 517.2858435918367},
#  {'magnetization_per_spin': 0.12,
#   'energy': -27.0,
#   'binder_cumulant': -0.6796735038624848,
#   'susceptibility_per_spin': 1393.0707554929577,
#   'specific_heat_per_spin': 504.05405268795863},
#  {'magnetization_per_spin': -0.06,
#   'energy': -5.0,
#   'binder_cumulant': -1.1298770501254318,
#   'susceptibility_per_spin': 1316.8238750000003,
#   'specific_heat_per_spin': 509.25843510802474},
#  {'magnetization_per_spin': -0.1,
#   'energy': -19.0,
#   'binder_cumulant': -0.8808527983355163,
#   'susceptibility_per_spin': 1100.7868443835614,
#   'specific_heat_per_spin': 358.2166302120472},
#  {'magnetization_per_spin': 0.36,
#   'energy': -67.0,
#   'binder_cumulant': -0.9151332608633262,
#   'susceptibility_per_spin': 1391.4033102702701,
#   'specific_heat_per_spin': 468.05478772826876},
#  {'magnetization_per_spin': -0.08,
#   'energy': -29.0,
#   'binder_cumulant': -0.788834201491281,
#   'susceptibility_per_spin': 827.7174101333333,
#   'specific_heat_per_spin': 464.81466247111115},
#  {'magnetization_per_spin': -0.18,
#   'energy': -23.0,
#   'binder_cumulant': -0.7397710912023954,
#   'susceptibility_per_spin': 1005.2513157894734,
#   'specific_heat_per_spin': 423.5276675207756},
#  {'magnetization_per_spin': -0.02,
#   'energy': -23.0,
#   'binder_cumulant': -0.7988654114217102,
#   'susceptibility_per_spin': 841.5128748051949,
#   'specific_heat_per_spin': 469.5704853432281},
#  {'magnetization_per_spin': 0.04,
#   'energy': -31.0,
#   'binder_cumulant': -0.8791071586248818,
#   'susceptibility_per_spin': 961.2403610256409,
#   'specific_heat_per_spin': 353.24349743589727},
#  {'magnetization_per_spin': -0.14,
#   'energy': -39.0,
#   'binder_cumulant': -1.1353774061149835,
#   'susceptibility_per_spin': 1188.2131032911393,
#   'specific_heat_per_spin': 317.1589398493831},
#  {'magnetization_per_spin': -0.16,
#   'energy': -9.0,
#   'binder_cumulant': -0.9107054830396173,
#   'susceptibility_per_spin': 834.109662,
#   'specific_heat_per_spin': 417.34800443750004},
#  {'magnetization_per_spin': -0.06,
#   'energy': -43.0,
#   'binder_cumulant': -0.991414945862811,
#   'susceptibility_per_spin': 1268.468937777778,
#   'specific_heat_per_spin': 268.921514159427},
#  {'magnetization_per_spin': 0.12,
#   'energy': -31.0,
#   'binder_cumulant': -0.8715676159733796,
#   'susceptibility_per_spin': 1022.7627897560974,
#   'specific_heat_per_spin': 306.6768584770969},
#  {'magnetization_per_spin': -0.04,
#   'energy': -1.0,
#   'binder_cumulant': -0.6507743758247619,
#   'susceptibility_per_spin': 1006.6235662650602,
#   'specific_heat_per_spin': 309.1055361300624},
#  {'magnetization_per_spin': 0.02,
#   'energy': -27.0,
#   'binder_cumulant': -0.9362140033421888,
#   'susceptibility_per_spin': 680.5140266666667,
#   'specific_heat_per_spin': 289.55494733560096},
#  {'magnetization_per_spin': 0.14,
#   'energy': -19.0,
#   'binder_cumulant': -0.6616574228407077,
#   'susceptibility_per_spin': 765.7387218823529,
#   'specific_heat_per_spin': 258.84312891349475},
#  {'magnetization_per_spin': 0.0,
#   'energy': -41.0,
#   'binder_cumulant': -0.7655520068118438,
#   'susceptibility_per_spin': 798.9791330232559,
#   'specific_heat_per_spin': 252.65670762574365},
#  {'magnetization_per_spin': 0.02,
#   'energy': -3.0,
#   'binder_cumulant': -0.840733607260933,
#   'susceptibility_per_spin': 1033.8318303448275,
#   'specific_heat_per_spin': 289.90342285638786},
#  {'magnetization_per_spin': -0.14,
#   'energy': -17.0,
#   'binder_cumulant': -0.6603101755075662,
#   'susceptibility_per_spin': 856.1099231818182,
#   'specific_heat_per_spin': 241.07871689049583},
#  {'magnetization_per_spin': 0.2,
#   'energy': -11.0,
#   'binder_cumulant': -0.6713846765318938,
#   'susceptibility_per_spin': 716.6460242696629,
#   'specific_heat_per_spin': 204.4998152253503},
#  {'magnetization_per_spin': -0.04,
#   'energy': -27.0,
#   'binder_cumulant': -0.7662701136813215,
#   'susceptibility_per_spin': 908.1390893333333,
#   'specific_heat_per_spin': 251.72479165432097},
#  {'magnetization_per_spin': -0.02,
#   'energy': -1.0,
#   'binder_cumulant': -1.1106243547839605,
#   'susceptibility_per_spin': 835.9428061538462,
#   'specific_heat_per_spin': 224.8169532665138},
#  {'magnetization_per_spin': -0.12,
#   'energy': -31.0,
#   'binder_cumulant': -0.7029073492434619,
#   'susceptibility_per_spin': 846.0157908695651,
#   'specific_heat_per_spin': 191.63812778827975},
#  {'magnetization_per_spin': -0.12,
#   'energy': -19.0,
#   'binder_cumulant': -0.9950147474975297,
#   'susceptibility_per_spin': 755.2672619354839,
#   'specific_heat_per_spin': 231.04823544918492},
#  {'magnetization_per_spin': 0.04,
#   'energy': -29.0,
#   'binder_cumulant': -0.8104068249018415,
#   'susceptibility_per_spin': 550.2636761702128,
#   'specific_heat_per_spin': 209.85594889090086},
#  {'magnetization_per_spin': 0.06,
#   'energy': -7.0,
#   'binder_cumulant': -0.9468240080756669,
#   'susceptibility_per_spin': 970.309032,
#   'specific_heat_per_spin': 200.27974626038784},
#  {'magnetization_per_spin': 0.08,
#   'energy': -31.0,
#   'binder_cumulant': -0.8573691485788115,
#   'susceptibility_per_spin': 519.9144516666665,
#   'specific_heat_per_spin': 179.71181072048606},
#  {'magnetization_per_spin': -0.12,
#   'energy': -29.0,
#   'binder_cumulant': -1.0275225460686976,
#   'susceptibility_per_spin': 604.0640952577319,
#   'specific_heat_per_spin': 181.24870192369002},
#  {'magnetization_per_spin': -0.22,
#   'energy': -19.0,
#   'binder_cumulant': -1.1117170058007475,
#   'susceptibility_per_spin': 598.8037942857143,
#   'specific_heat_per_spin': 193.60702640566427},
#  {'magnetization_per_spin': -0.06,
#   'energy': -21.0,
#   'binder_cumulant': -1.5502513618550733,
#   'susceptibility_per_spin': 554.3478690909091,
#   'specific_heat_per_spin': 181.22744111825324},
#  {'magnetization_per_spin': 0.14,
#   'energy': -33.0,
#   'binder_cumulant': -0.649781952115259,
#   'susceptibility_per_spin': 788.70119,
#   'specific_heat_per_spin': 136.64863936},
#  {'magnetization_per_spin': 0.04,
#   'energy': 1.0,
#   'binder_cumulant': -0.8325795990898879,
#   'susceptibility_per_spin': 891.9837588118811,
#   'specific_heat_per_spin': 139.37926081756686},
#  {'magnetization_per_spin': 0.06,
#   'energy': -11.0,
#   'binder_cumulant': -1.232107666056224,
#   'susceptibility_per_spin': 673.7723133333333,
#   'specific_heat_per_spin': 162.8064035371011},
#  {'magnetization_per_spin': 0.04,
#   'energy': -15.0,
#   'binder_cumulant': -0.6270408412051556,
#   'susceptibility_per_spin': 773.0340811650485,
#   'specific_heat_per_spin': 147.03067474785558},
#  {'magnetization_per_spin': 0.02,
#   'energy': -31.0,
#   'binder_cumulant': -0.9849901799365037,
#   'susceptibility_per_spin': 532.2145707692308,
#   'specific_heat_per_spin': 144.70294197485205},
#  {'magnetization_per_spin': 0.12,
#   'energy': -9.0,
#   'binder_cumulant': -1.107922850958281,
#   'susceptibility_per_spin': 814.5214537142857,
#   'specific_heat_per_spin': 132.03076901587303},
#  {'magnetization_per_spin': 0.06,
#   'energy': -17.0,
#   'binder_cumulant': -1.0525051852848986,
#   'susceptibility_per_spin': 749.4501701886792,
#   'specific_heat_per_spin': 136.06960480598073},
#  {'magnetization_per_spin': -0.04,
#   'energy': -25.0,
#   'binder_cumulant': -0.699610002365141,
#   'susceptibility_per_spin': 512.0902444859812,
#   'specific_heat_per_spin': 122.76649265438026},
#  {'magnetization_per_spin': 0.12,
#   'energy': 3.0,
#   'binder_cumulant': -0.7684648299842616,
#   'susceptibility_per_spin': 469.2048114814815,
#   'specific_heat_per_spin': 125.88600737311384},
#  {'magnetization_per_spin': -0.12,
#   'energy': -9.0,
#   'binder_cumulant': -1.0296380290949805,
#   'susceptibility_per_spin': 545.180111559633,
#   'specific_heat_per_spin': 118.0283889908257},
#  {'magnetization_per_spin': 0.28,
#   'energy': -3.0,
#   'binder_cumulant': -0.8177357203394042,
#   'susceptibility_per_spin': 753.5920985454546,
#   'specific_heat_per_spin': 123.86082085950414},
#  {'magnetization_per_spin': -0.18,
#   'energy': -11.0,
#   'binder_cumulant': -1.4553636823409248,
#   'susceptibility_per_spin': 684.2821981981981,
#   'specific_heat_per_spin': 114.68821397613826},
#  {'magnetization_per_spin': -0.26,
#   'energy': -13.0,
#   'binder_cumulant': -0.7811371848700066,
#   'susceptibility_per_spin': 611.7993771428571,
#   'specific_heat_per_spin': 125.44916425382651},
#  {'magnetization_per_spin': 0.12,
#   'energy': 3.0,
#   'binder_cumulant': -1.1309522236668164,
#   'susceptibility_per_spin': 699.1007968141593,
#   'specific_heat_per_spin': 111.92411869371135},
#  {'magnetization_per_spin': -0.2,
#   'energy': -23.0,
#   'binder_cumulant': -1.4560644895173933,
#   'susceptibility_per_spin': 444.03507508771924,
#   'specific_heat_per_spin': 92.13642816251154},
#  {'magnetization_per_spin': 0.02,
#   'energy': -3.0,
#   'binder_cumulant': -1.0350822801288886,
#   'susceptibility_per_spin': 584.4026542608694,
#   'specific_heat_per_spin': 100.8432373837429},
#  {'magnetization_per_spin': 0.08,
#   'energy': 11.0,
#   'binder_cumulant': -0.7158064665932498,
#   'susceptibility_per_spin': 495.24585344827585,
#   'specific_heat_per_spin': 86.57196643876337},
#  {'magnetization_per_spin': 0.06,
#   'energy': 7.0,
#   'binder_cumulant': -0.7964285796853601,
#   'susceptibility_per_spin': 737.4100427350428,
#   'specific_heat_per_spin': 119.4001312294543},
#  {'magnetization_per_spin': 0.04,
#   'energy': -27.0,
#   'binder_cumulant': -0.7538721728754776,
#   'susceptibility_per_spin': 474.84558338983044,
#   'specific_heat_per_spin': 117.96292915828784},
#  {'magnetization_per_spin': -0.22,
#   'energy': -5.0,
#   'binder_cumulant': -1.201389536252318,
#   'susceptibility_per_spin': 428.32416806722694,
#   'specific_heat_per_spin': 68.58432367770637},
#  {'magnetization_per_spin': 0.06,
#   'energy': -29.0,
#   'binder_cumulant': -0.7238217764114416,
#   'susceptibility_per_spin': 570.6831250000001,
#   'specific_heat_per_spin': 90.1924701111111},
#  {'magnetization_per_spin': 0.14,
#   'energy': -7.0,
#   'binder_cumulant': -2.04534329974399,
#   'susceptibility_per_spin': 439.80921123966937,
#   'specific_heat_per_spin': 108.18284423195134},
#  {'magnetization_per_spin': 0.1,
#   'energy': -15.0,
#   'binder_cumulant': -1.04874226937469,
#   'susceptibility_per_spin': 459.2473586885245,
#   'specific_heat_per_spin': 104.55274901908086},
#  {'magnetization_per_spin': 0.06,
#   'energy': -9.0,
#   'binder_cumulant': -0.8955352655787827,
#   'susceptibility_per_spin': 445.035082601626,
#   'specific_heat_per_spin': 97.868737286007},
#  {'magnetization_per_spin': 0.16,
#   'energy': -27.0,
#   'binder_cumulant': -1.126039251251636,
#   'susceptibility_per_spin': 739.6070319354839,
#   'specific_heat_per_spin': 86.51014568158165},
#  {'magnetization_per_spin': 0.06,
#   'energy': -1.0,
#   'binder_cumulant': -0.6088057027044014,
#   'susceptibility_per_spin': 439.32323712,
#   'specific_heat_per_spin': 84.96281024},
#  {'magnetization_per_spin': 0.06,
#   'energy': -39.0,
#   'binder_cumulant': -0.9878123710261117,
#   'susceptibility_per_spin': 484.45968222222217,
#   'specific_heat_per_spin': 92.26225182665655},
#  {'magnetization_per_spin': -0.08,
#   'energy': -21.0,
#   'binder_cumulant': -0.6955516908314621,
#   'susceptibility_per_spin': 557.554342992126,
#   'specific_heat_per_spin': 76.79633316386632},
#  {'magnetization_per_spin': 0.02,
#   'energy': -35.0,
#   'binder_cumulant': -0.6496485146025093,
#   'susceptibility_per_spin': 601.3447971875,
#   'specific_heat_per_spin': 81.37852927246092},
#  {'magnetization_per_spin': -0.08,
#   'energy': -1.0,
#   'binder_cumulant': -0.8465829405064254,
#   'susceptibility_per_spin': 510.57810573643405,
#   'specific_heat_per_spin': 84.54896967730303}]

# %%
model.plot()
