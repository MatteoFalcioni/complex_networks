# %%
from euclidianNetwork import EuclidianNetwork
from isingNetwork import IsingModel
import numpy as np

# %%
g = EuclidianNetwork(100,2)
g.show()
g.show_adjacency_matrix()

# %%
model = IsingModel(g.get_graph(), 1, 10000, 1)

temperature = np.arange(1, 10, 0.1)

#model.viz(temperature)
model.viz(temperature)
# Out:
# 100%|██████████| 90/90 [09:53<00:00,  6.59s/it]
# array([{'magnetization_per_spin': 0.94, 'energy': -129.0},
#        {'magnetization_per_spin': 0.62, 'energy': -117.0},
#        {'magnetization_per_spin': 1.0, 'energy': -137.0},
#        {'magnetization_per_spin': 0.5, 'energy': -109.0},
#        {'magnetization_per_spin': -0.32, 'energy': -99.0},
#        {'magnetization_per_spin': -0.32, 'energy': -103.0},
#        {'magnetization_per_spin': 0.24, 'energy': -77.0},
#        {'magnetization_per_spin': 0.38, 'energy': -97.0},
#        {'magnetization_per_spin': 0.16, 'energy': -79.0},
#        {'magnetization_per_spin': 0.24, 'energy': -73.0},
#        {'magnetization_per_spin': -0.08, 'energy': -95.0},
#        {'magnetization_per_spin': 0.18, 'energy': -65.0},
#        {'magnetization_per_spin': 0.06, 'energy': -83.0},
#        {'magnetization_per_spin': -0.2, 'energy': -55.0},
#        {'magnetization_per_spin': -0.18, 'energy': -59.0},
# ...
